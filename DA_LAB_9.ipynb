# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
np.random.seed(42)
data = np.random.normal(loc=100, scale=15, size=1000)
sns.histplot(data, bins=30, kde=True, stat="density", color="blue")
x = np.linspace(min(data), max(data), 100)
plt.plot(x, stats.norm.pdf(x, 100, 15), 'r-', label="Theoretical Normal Curve")
plt.legend()
plt.xlabel("Value")
plt.ylabel("Density")
plt.title("Histogram and Normal Curve")
plt.show()

# %%
variable = df["heart_rate"]
mean, std = np.mean(variable), np.std(variable)
skewness, kurtosis = stats.skew(variable), stats.kurtosis(variable)
print(f"Mean: {mean}, Std Dev: {std}, Skewness: {skewness}, Kurtosis: {kurtosis}")
sns.histplot(variable, bins=30, kde=True, color="purple")
plt.title("Histogram and KDE of Heart Rate")
plt.show()
stats.probplot(variable, dist="norm", plot=plt)
plt.title("Q-Q Plot")
plt.show()
shapiro_test = stats.shapiro(variable)
print(f"Shapiro-Wilk test p-value: {shapiro_test.pvalue}")
# Out:
# Mean: 80.70836237249155, Std Dev: 9.969555252946302, Skewness: -0.049321773965296536, Kurtosis: 0.05211754569784155
# Shapiro-Wilk test p-value: 0.7311929770362118

# %%
prob_less_than_80 = stats.norm.cdf(80, mean, std)
print(f"P(Heart Rate < 80): {prob_less_than_80}")
percentile_90 = stats.norm.ppf(0.90, mean, std)
print(f"90th percentile of Heart Rate: {percentile_90}")
pdf_100 = stats.norm.pdf(100, mean, std)
print(f"PDF at Heart Rate = 100: {pdf_100}")
generated_data = np.random.normal(mean, std, 1000)
sns.histplot(generated_data, bins=30, kde=True, color="green", label="Generated Data")
sns.histplot(variable, bins=30, kde=True, color="blue", alpha=0.5, label="Real Data")
plt.legend()
plt.title("Comparison of Real and Generated Distributions")
plt.show()
# Out:
# P(Heart Rate < 80): 0.47167796417062724
# 90th percentile of Heart Rate: 93.48486151468828
# PDF at Heart Rate = 100: 0.006153751320343601

# %%
ci_low, ci_high = stats.norm.interval(0.95, loc=mean, scale=std/np.sqrt(len(variable)))
print(f"95% CI for Mean Heart Rate: ({ci_low}, {ci_high})")
prob_bp_greater_150 = 1 - stats.norm.cdf(150, df["systolic_bp"].mean(), df["systolic_bp"].std())
print(f"P(Systolic BP > 150): {prob_bp_greater_150}")
# Out:
# 95% CI for Mean Heart Rate: (80.09045429048535, 81.32627045449775)
# P(Systolic BP > 150): 0.021294631012716225
